# %%
Programa Looping
var
  x, r, i: Inteiro
Inicio
  para i de 1 até 4 passo 1 faça
    leia(x)
    r <- x*12
    escreva(r)
  fimpara
fimalgoritmo
# Out:
#   File "<ipython-input-8-1cad83861d93>", line 1
#     Programa Looping
#              ^
# SyntaxError: invalid syntax

# %%
for i in range (4):
  x=float(input("Digite um valor para x:"))
  r=x*12
  print(f"O valor de R é {r}")
# Out:
# Digite um valor para x:2
# O valor de R é 6.0
# Digite um valor para x:2.5
# O valor de R é 7.5
# Digite um valor para x:3.53
# O valor de R é 10.59
# Digite um valor para x:2222
# O valor de R é 6666.0
# Digite um valor para x:666
# O valor de R é 1998.0
